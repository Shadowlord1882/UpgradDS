# %%
import string
input_string = 'I am now a master of Logistic regression'
print(string.capwords(input_string))
# Out:
# I Am Now A Master Of Logistic Regression

# %%
input_list = [7, 2, 0, 9, -1, 8]
input_list.sort()

uniqnum=set(input_list)
input_list=list(uniqnum)
input_list.sort()
if len(input_list) == 1:
    print('not present')
elif len(input_list) > 1:
    print(input_list[-2])
# Out:
# 8

# %%
import pandas as pd
wholesale = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/OkbnaOBqrBXZOpRQw1JGMgaM9/Wholesale_Data.csv')
#varlist=['Channel']
wholesale
# Out:
#      Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen     Channel
# 0    12669  9656     7561     214              2674        1338        Cafe
# 1     7057  9810     9568    1762              3293        1776         Hot
# 2     6353  8808     7684    2405              3516        7844       Hotel
# 3    13265  1196     4221    6404               507        1788           C
# 4    22615  5410     7198    3915              1777        5185           H
# ..     ...   ...      ...     ...               ...         ...         ...
# 365   4692  6128     8025    1619              4515        3105        Cafe
# 366   9561  2217     1664    1173               222         447         Hot
# 367   3477   894      534    1457               252         342  Restaurant
# 368  22335  1196     2406    2046               101         558        Rest
# 369   6211   337      683    1089                41         296           H
#
# [370 rows x 7 columns]

# %%
import pandas as pd
wholesale = pd.read_csv('https://media-doselect.s3.amazonaws.com/generic/OkbnaOBqrBXZOpRQw1JGMgaM9/Wholesale_Data.csv')
varlist=['Channel']
wholesale[varlist]=wholesale[varlist].apply(lambda x:x.map({'C':'Cafe','Cafe':'Cafe','Caffe':'Cafe','H':'Hotel','Hot':'Hotel','Hotel':'Hotel','Hote':'Hotel','R':'Restaurant','Rest':'Restaurant','Restaurant':'Restaurant'}))
wholesale
# Out:
#      Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen     Channel
# 0    12669  9656     7561     214              2674        1338        Cafe
# 1     7057  9810     9568    1762              3293        1776       Hotel
# 2     6353  8808     7684    2405              3516        7844       Hotel
# 3    13265  1196     4221    6404               507        1788        Cafe
# 4    22615  5410     7198    3915              1777        5185       Hotel
# ..     ...   ...      ...     ...               ...         ...         ...
# 365   4692  6128     8025    1619              4515        3105        Cafe
# 366   9561  2217     1664    1173               222         447       Hotel
# 367   3477   894      534    1457               252         342  Restaurant
# 368  22335  1196     2406    2046               101         558  Restaurant
# 369   6211   337      683    1089                41         296       Hotel
#
# [370 rows x 7 columns]
